# %%
#import modul yang dibutuhkan
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from pdb import set_trace as bp ##for testing
import re
import time
import csv

# %%
#running chromedriver
outputFileName='result'
link = "https://play.google.com/store/apps/details?id=com.sterling.ireappro&showAllReviews=true"
driver = webdriver.Chrome('chromedriver.exe')
driver.get(link)

# %%
title = driver.find_element_by_xpath('/html/head/meta[9]').get_attribute('content')

print(title)
# Out:
# iREAP PRO: Cashier / POS Online & Offline - Apps on Google Play

# %%
# scrolling data
flag=0
while 1:
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    try:
        loadMore=driver.find_element_by_xpath("//*[contains(@class,'U26fgb O0WRkf oG5Srb C0oVfc n9lfJ')]").click()
    except:
        time.sleep(1)
        flag=flag+1
        if flag >= 10:
            break
    else:
        flag=0
reviews=driver.find_elements_by_xpath("//*[@jsname='fk8dgd']//div[@class='d15Mdf bAhLNe']")

# %%
idx_review = 1

# ini nama user-nya
nama_user = reviews[idx_review].find_element_by_xpath(".//span[@class='X43Kjb']").text
# ini tanggal review-nya
tanggal_review = reviews[idx_review].find_element_by_xpath(".//span[@class='p2TkOb']").text
# ini teks review-nya
review_user = reviews[idx_review].find_element_by_xpath(".//span[@jsname='bN97Pc']").text

print("Nama user: " + nama_user)
print("Tanggal review: " + tanggal_review)
print("Review: " + review_user)
# Out:
# Nama user: Hi10 Thk
# Tanggal review: March 21, 2020
# Review: For products need to add photo options, so we can show product picture to coustmors

# %%
reviews_df = []
for index, review in enumerate(reviews, start=0):
    print('[' + str(index + 1) + ']--------------------------------------------------')
    # ini nama user-nya
    nama_user = reviews[index].find_element_by_xpath(".//span[@class='X43Kjb']").text
    # ini tanggal review-nya
    tanggal_review = reviews[index].find_element_by_xpath(".//span[@class='p2TkOb']").text
    # ini teks review-nya
    review_user = reviews[index].find_element_by_xpath(".//span[@jsname='bN97Pc']").text

    print("Nama user: " + nama_user)
    print("Tanggal review: " + tanggal_review)
    print("Review: " + review_user)
    print('--------------------------------------------------')
    
    temp = pd.DataFrame({'Nama':nama_user,'Tanggal':tanggal_review,'Reviews':review_user},index=[1])
    print('-'*10)
    reviews_df.append(temp)
    #print(elem)
# Out:
# [1]--------------------------------------------------
# Nama user: Nwokoro Peter
# Tanggal review: February 24, 2020
# Review: very useful, second to none, but improve on expenses feature.
# --------------------------------------------------
# ----------
# [2]--------------------------------------------------
# Nama user: Hi10 Thk
# Tanggal review: March 21, 2020
# Review: For products need to add photo options, so we can show product picture to coustmors
# --------------------------------------------------
# ----------
# [3]--------------------------------------------------
# Nama user: Siliki Sprei
# Tanggal review: November 15, 2019
# Review: Nice to trial this app , very usefull and Simple
# --------------------------------------------------
# ----------
# [4]--------------------------------------------------
# Nama user: Irish De Luna
# Tanggal review: May 13, 2019
# Review: Please provide customer loyalty program also that allow us to give point to our customers that they can accumulate upon purchasing. This will really help us to attract more customer other than that this app really amazing
# --------------------------------------------------
# ----------
# [5]--------------------------------------------------
# Nama user: Yulianto 9unawan
# Tanggal review: November 15, 2019
# Review: I am Coffeepreneur with brand Nomar Kopi, found this application is very sophisticated for estimate cost and inventory management. I applied to every outlet until our outlet in Holland and Suriname. Thank you Ireap for such a wonderful POS System
# --------------------------------------------------
# ----------
# [6]--------------------------------------------------
# Nama user: Bindawood Nig LTD
# Tanggal review: September 22, 2019
# Review: Why is it not running on iOS and windows?
# --------------------------------------------------
# ----------
# [7]--------------------------------------------------
# Nama user: Tri Ratna Sari
# Tanggal review: March 18, 2020
# Review: So far so good
# --------------------------------------------------
# ----------
# [8]--------------------------------------------------
# Nama user: renan banayad
# Tanggal review: May 5, 2019
# Review: I got what I paid
# --------------------------------------------------
# ----------
# [9]--------------------------------------------------
# Nama user: Risnawan Budianto
# Tanggal review: October 26, 2018
# Review: Good POS apps
# --------------------------------------------------
# ----------
# [10]--------------------------------------------------
# Nama user: David Hermawan
# Tanggal review: May 4, 2020
# Review: Kebutuhan: kontrol stok keluar masuk gudang 1 admin untuk lihat report 3 staff untuk scan barcode barang masuk dan keluar Jadi butuh brp license? Sy WA ke nomer support ga dibalas
# --------------------------------------------------
# ----------
# [11]--------------------------------------------------
# Nama user: alwi abdurrahman
# Tanggal review: November 23, 2019
# Review: Good
# --------------------------------------------------
# ----------
# [12]--------------------------------------------------
# Nama user: Mahmud Steel
# Tanggal review: October 23, 2019
# Review: Kenapa wa support slow respond ya. Padahal sy user baru butuh bimbingan. Thx
# --------------------------------------------------
# ----------
# [13]--------------------------------------------------
# Nama user: andria taurisia
# Tanggal review: August 11, 2019
# Review: saya intall juga ireap pro helper di hp yang lain.. knp tidak bisa connect ke hp master device nya?? apakah di hp pro helper ada ya g perlu di install selain masukkan ip server master
# --------------------------------------------------
# ----------
# [14]--------------------------------------------------
# Nama user: Johannes Ricky Enggung
# Tanggal review: June 22, 2019
# Review: Finally, I can see all transaction, stock and profit in my stores anywhere and anytime via web.
# --------------------------------------------------
# ----------
# [15]--------------------------------------------------
# Nama user: Ida Royani
# Tanggal review: July 17, 2019
# Review: cara penggunaan gmna mf bru pake masih bingung
# --------------------------------------------------
# ----------
# [16]--------------------------------------------------
# Nama user: Gila Kopi
# Tanggal review: July 14, 2019
# Review: good POS
# --------------------------------------------------
# ----------
# [17]--------------------------------------------------
# Nama user: One Liar
# Tanggal review: April 25, 2019
# Review: harganya berapa ya? ini bisa lifetime ngga ya sekali bayar gitu..
# --------------------------------------------------
# ----------
# [18]--------------------------------------------------
# Nama user: Hasan Pranowo
# Tanggal review: April 11, 2019
# Review: aplikasi bagus, tampilannya sangat clean, fresh look, tapi kayaknya masih perlu pengembangan terutama di management harga dan management promosi/discount nya.
# --------------------------------------------------
# ----------
# [19]--------------------------------------------------
# Nama user: Iwan Witanto
# Tanggal review: December 4, 2018
# Review: Very helpfull
# --------------------------------------------------
# ----------
# [20]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: October 17, 2018
# Review: Tidak ada versi bahasa indonesia?
# --------------------------------------------------
# ----------
# [21]--------------------------------------------------
# Nama user: yafi hibrizi
# Tanggal review: October 24, 2018
# Review: Kalo habis masa trial ... Gmn?
# --------------------------------------------------
# ----------
# [22]--------------------------------------------------
# Nama user: zyto yto
# Tanggal review: October 20, 2018
# Review: Good app
# --------------------------------------------------
# ----------
# [23]--------------------------------------------------
# Nama user: Rizki Teto
# Tanggal review: October 5, 2018
# Review: Bayar krg Dr 100rbu sudah dapat fitur product set. So far bagus bgt dibanding yg lain
# --------------------------------------------------
# ----------
# [24]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: August 17, 2018
# Review: Sudah bagus. Ke depan mungkin bisa ditambahkan fitur untuk cetak label (alamat pengiriman barang). Akan sangat membantu online shop tentunya. Terima kasih.
# --------------------------------------------------
# ----------
# [25]--------------------------------------------------
# Nama user: Sidik Trianto
# Tanggal review: September 1, 2018
# Review: Saya mencoba trial..di sini belum ada untuk pengeluaran yaa?
# --------------------------------------------------
# ----------
# [26]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: September 21, 2018
# Review: Adakah no wa bagian supportnya..?
# --------------------------------------------------
# ----------
# [27]--------------------------------------------------
# Nama user: yoni wahyu nuryanto
# Tanggal review: July 31, 2018
# Review: Bagus dan cukup lengkap fiturnya. Tolong ditambahkan fitur alert untuk stok barang yg mulai habis karena itu penting. Terimakasih
# --------------------------------------------------
# ----------
# [28]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: August 3, 2018
# Review: We use ireap in our hair salon which it it works ready well.
# --------------------------------------------------
# ----------
# [29]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: July 18, 2018
# Review: Very good & usefull POS application
# --------------------------------------------------
# ----------
# [30]--------------------------------------------------
# Nama user: Satrio Ayom Santoso
# Tanggal review: July 14, 2018
# Review: Ok
# --------------------------------------------------
# ----------
# [31]--------------------------------------------------
# Nama user: Garry Susanto
# Tanggal review: June 27, 2018
# Review: Tolong tambahkan fitur pengeluaran (modal kasir) Ada sedikit masalah di apps saya tapi sedang di tangani semoga cepat bisa digunakan kembali
# --------------------------------------------------
# ----------
# [32]--------------------------------------------------
# Nama user: adli kamil mohd
# Tanggal review: May 17, 2018
# Review: Very useful
# --------------------------------------------------
# ----------
# [33]--------------------------------------------------
# Nama user: Pacifico Terrado
# Tanggal review: July 24, 2018
# Review: It would be great if you are able to transfer items from one store to another. Transferring items from one store to another manually will possibly introduce error.
# --------------------------------------------------
# ----------
# [34]--------------------------------------------------
# Nama user: AVL GAMING
# Tanggal review: April 24, 2018
# Review: hello developer can u tell me what different ireap lite and pro thanks
# --------------------------------------------------
# ----------
# [35]--------------------------------------------------
# Nama user: Andhika Pradana
# Tanggal review: April 20, 2018
# Review: Bagus. Mudah dipahami dan tersedia free trial 14 hari sebelum memutuskan untuk beli. Kalau boleh saran ditambahkan menu tutorial atau how to di dalam aplikasinya agar semakin memudahkan. Dan mau tanya, ini untuk historis penjualannya ga bisa ketauan ya transaksi dilakukan oleh user yg mana? Jadi...
# Full Review
# --------------------------------------------------
# ----------
# [36]--------------------------------------------------
# Nama user: KotaTua Kopi
# Tanggal review: May 1, 2018
# Review: Ireap tolong berikan fitur pengeluaran lainnya juga dong tiap toko kan pengelurannya gak melulu produk tp ada operasional juga
# --------------------------------------------------
# ----------
# [37]--------------------------------------------------
# Nama user: Climb Asend
# Tanggal review: March 25, 2018
# Review: Simple to use and easy for accounting.
# --------------------------------------------------
# ----------
# [38]--------------------------------------------------
# Nama user: Sabros Salim
# Tanggal review: April 6, 2018
# Review: Good and simple to use 😊
# --------------------------------------------------
# ----------
# [39]--------------------------------------------------
# Nama user: Fransiscus Sonix Masuli
# Tanggal review: March 10, 2018
# Review: I like it!
# --------------------------------------------------
# ----------
# [40]--------------------------------------------------
# Nama user: rene cacas
# Tanggal review: January 25, 2018
# Review: Can you put a share tab on goods issue and goods received. This will serve as an alternative to print good issue and received using generic by printer
# --------------------------------------------------
# ----------
# [41]--------------------------------------------------
# Nama user: Yanwar Aprianto
# Tanggal review: February 1, 2018
# Review: Bisakah ganti bahasa?
# --------------------------------------------------
# ----------
# [42]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: January 20, 2018
# Review: Good.
# --------------------------------------------------
# ----------
# [43]--------------------------------------------------
# Nama user: sunz yo
# Tanggal review: December 16, 2017
# Review: So far bgs tp syg tdk ada batasan antara owner dan karyawan, harusnya yg di web bisa untuk akses owner sedangkan yg di aplikasi untuk akses karyawan kasir dan waitres, dan per karyawan dpt akses masing2 jadi nantinya akan jelas siapa yg handle dan siapa yg bertanggung jawab, jadi sistem stok in dan ...
# Full Review
# --------------------------------------------------
# ----------
# [44]--------------------------------------------------
# Nama user: Hanjaya Ekaputra
# Tanggal review: December 29, 2017
# Review: iReap, really helpful for simple POS system, better included with PC ones. So far so good. Excellent customer service help from WhatsApp. Keep up the good job
# --------------------------------------------------
# ----------
# [45]--------------------------------------------------
# Nama user: Budiana I Nyoman Gede
# Tanggal review: January 4, 2018
# Review: bisa dibuatkan multi satuan.1 jenis barang satuannya kan banyak.misal pewarna satuan dus bal pak pcs.jadi tidak mesti bikin beberapa stock.suoaya bisa dijual per dus atau pcs
# --------------------------------------------------
# ----------
# [46]--------------------------------------------------
# Nama user: Dave Evan
# Tanggal review: January 3, 2018
# Review: Easy use
# --------------------------------------------------
# ----------
# [47]--------------------------------------------------
# Nama user: Abbe Havied Darwinsyah
# Tanggal review: November 8, 2017
# Review: Kenapa setiap kali login di apps, previous key in sales atau melihat daily sales kosong? Tetapi di web ada..
# --------------------------------------------------
# ----------
# [48]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: November 27, 2017
# Review: Gimana caranya utk beli aplikasinya?
# --------------------------------------------------
# ----------
# [49]--------------------------------------------------
# Nama user: yaku sina
# Tanggal review: September 21, 2017
# Review: Dear Team, Saya tidak bisa mengganti pengaturan di general setting kec bagian negative stock. Bagaimana caranya ya? Lalu pengaturan bahasa tidak adakah? Dan bagaimana untuk meng-input harga modal?
# --------------------------------------------------
# ----------
# [50]--------------------------------------------------
# Nama user: yana sidik
# Tanggal review: September 21, 2017
# Review: DEAR IPeap Pro... . Macam Mana Nak set Kan quantiti barang yang ada dalam kedai.? . Contoh Barang A quantiti nyaa 24 helai.. mcm mana nak setkan... . Adakah perlu membeli full version dahulu. . Apps ini sangat mudah diguna kan. . Cuma sy confius mcm mana nak add quantiti sesuatu barang... . Adakah p...
# Full Review
# --------------------------------------------------
# ----------
# [51]--------------------------------------------------
# Nama user: tri joko
# Tanggal review: August 9, 2017
# Review: Dear team i Reap Pos,Aplikasi yg keren mudah di pakai dan menarik dan lumayan lengkap untuk app pos portable. #Pertanyaan 1.saya menggunakan printer thermal .hasil printer tulisanya kecil2 jadi susah di baca..apakah ada setingan besar huruf.? 2.bagai mana cara agar tetap aktif aplikasi ini ? terim...
# Full Review
# --------------------------------------------------
# ----------
# [52]--------------------------------------------------
# Nama user: fire breathing
# Tanggal review: July 26, 2017
# Review: Bisa tidak, apabila kasir menggunakan laptop , dan print receipt dari laptop, karena mencari printer yang supported by iReap di android apps agak susah
# --------------------------------------------------
# ----------
# [53]--------------------------------------------------
# Nama user: MIKE SSN750
# Tanggal review: September 10, 2017
# Review: Maaf rate tengah tengah kalau bisa input gambar pada barang yg akan dijual aku kasih rate maksimal. Tolong kedepanya dikasih mode gambar pada barang yg akan dijual. Terus kalau bisa aplikasi dijual aja tidak usah pakai langganan hehehe ^^v
# --------------------------------------------------
# ----------
# [54]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: August 28, 2017
# Review: This aps is very good but there is room for improvement. Hope to have multiple device on one merchant and sales on those unpaid yet
# --------------------------------------------------
# ----------
# [55]--------------------------------------------------
# Nama user: Nina Lusiana
# Tanggal review: August 31, 2017
# Review: Dear team iReap Pos, Utk printer thermal HP-M200 gak bisa yah?
# --------------------------------------------------
# ----------
# [56]--------------------------------------------------
# Nama user: nicholas mugambi
# Tanggal review: July 22, 2017
# Review: Please give the cashier authority to create customer, very important because it will assist a business to keep a database of all customers. Otherwise this is the best android pos so far
# --------------------------------------------------
# ----------
# [57]--------------------------------------------------
# Nama user: widayanto setio
# Tanggal review: July 5, 2017
# Review: Tambahin fitur sub kategori donk, biar lbh spesifik dalam mengelompokkan barang
# --------------------------------------------------
# ----------
# [58]--------------------------------------------------
# Nama user: M Afif
# Tanggal review: June 6, 2017
# Review: Saya ingin subscribe 1 th .. Tapi tolong ditambahkan untuk bisa 1 toko bisa multyple kasir .. Jd data antar kasir bisa langsung saling melengkapi.. Karena unk toko online dengan CS yg banyak pakai sistem yg sekarang masih kurang optimal
# --------------------------------------------------
# ----------
# [59]--------------------------------------------------
# Nama user: muhammad azlan kamarudin
# Tanggal review: May 11, 2017
# Review: Cannot add category of the item. Pressing the column box does nothing. Cannot write in it. Please help.
# --------------------------------------------------
# ----------
# [60]--------------------------------------------------
# Nama user: ASZA VAPOR
# Tanggal review: May 10, 2017
# Review: Bisa saya tambah untuk cashier pakai phone lain ?
# --------------------------------------------------
# ----------
# [61]--------------------------------------------------
# Nama user: enwe data
# Tanggal review: May 12, 2017
# Review: apakah proses transaksinya bisa menggunakan laptop ?
# --------------------------------------------------
# ----------
# [62]--------------------------------------------------
# Nama user: CHRISTOPHER MARASIGAN
# Tanggal review: May 14, 2017
# Review: I like it
# --------------------------------------------------
# ----------
# [63]--------------------------------------------------
# Nama user: JESUS loves iggy
# Tanggal review: April 30, 2017
# Review: PUJI TUHAN...program ini luar biasa. Sejak lama saya mencari dan membutuhkan program ini. Tidak ada kata selain LUAR BIASA dan terima kasih atas bantuan membuatkan program ini. Seandainya bisa ditambahkan foto produk, akan sangat membantu. Mohon maaf kalau permintaan ini berlebihan. On behalf of R...
# Full Review
# --------------------------------------------------
# ----------
# [64]--------------------------------------------------
# Nama user: Iqbal Hanif
# Tanggal review: April 28, 2017
# Review: Just the android pos i was looking for Thanks to entire team
# --------------------------------------------------
# ----------
# [65]--------------------------------------------------
# Nama user: Syaiful Burhan
# Tanggal review: April 16, 2017
# Review: Saya mau buat diskon di ireap pro kok gak ada ya menunya? Udah di cari2 tetap ga ada
# --------------------------------------------------
# ----------
# [66]--------------------------------------------------
# Nama user: Diablo Stallion
# Tanggal review: April 13, 2017
# Review: Like this app so much
# --------------------------------------------------
# ----------
# [67]--------------------------------------------------
# Nama user: Leonard Merari
# Tanggal review: February 24, 2017
# Review: Hi, baru aja download dan nyona iReap Pro.Untuk Product set and Product (keperluan BOM/Receipe) , apakah bisa menggunakan impor/expor CSV file? Thanks
# --------------------------------------------------
# ----------
# [68]--------------------------------------------------
# Nama user: Java King’s
# Tanggal review: March 11, 2017
# Review: Untuk menghapus item yang sudah d entri darimana
# --------------------------------------------------
# ----------
# [69]--------------------------------------------------
# Nama user: putri septysha
# Tanggal review: March 24, 2017
# Review: Gimana kalo add ke new device?
# --------------------------------------------------
# ----------
# [70]--------------------------------------------------
# Nama user: RadenCaesar Official
# Tanggal review: February 21, 2017
# Review: Nice apps
# --------------------------------------------------
# ----------
# [71]--------------------------------------------------
# Nama user: Global Publisher
# Tanggal review: January 16, 2017
# Review: min, kenapa diweb stok ada di admin ada tp di casir gk update?
# --------------------------------------------------
# ----------
# [72]--------------------------------------------------
# Nama user: shanker sharma
# Tanggal review: January 5, 2017
# Review: i want to go for pro software but i have two confusion can it work without internet means when internet start work its sync. and second can you give payment method facilty to admin. like now there are many payment mehtod paytm, online, credit facility
# --------------------------------------------------
# ----------
# [73]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: January 2, 2017
# Review: Pengembangan request saya sebelumnya sudah sangat baik, hanyaa da 1 hal lagi yg perlu ditambahkan, yaitu : daftar barang pada halaman sales harusnya diberikan setting untuk sort by product name alphabet atau id barang, sehingga memudahkan pencarian. Terimakasih..
# --------------------------------------------------
# ----------
# [74]--------------------------------------------------
# Nama user: Nchimunya Sinachikupo
# Tanggal review: December 27, 2016
# Review: The app does not provide cash up option. It does not however provide expense and other running costs for the show
# --------------------------------------------------
# ----------
# [75]--------------------------------------------------
# Nama user: Area51 Manado
# Tanggal review: December 26, 2016
# Review: Halo, bisa request fitur Sales By User gak ?? soalnya saya memiliki kasir lebih dari 1,.. thanks..
# --------------------------------------------------
# ----------
# [76]--------------------------------------------------
# Nama user: Rudi Yanto
# Tanggal review: December 30, 2016
# Review: Dear sterling team.. kenapa tidak bisa add user pada menu manage user ?thx
# --------------------------------------------------
# ----------
# [77]--------------------------------------------------
# Nama user: Yohanes Setiawan
# Tanggal review: December 31, 2016
# Review: Helpful and easy
# --------------------------------------------------
# ----------
# [78]--------------------------------------------------
# Nama user: yermia agus
# Tanggal review: October 18, 2016
# Review: Mohon ditambahkan fitur lost and breakage, daily cost, salary and bonus, serta fitur lock. Saya coba login menggunakan user cashier masih bisa melihat lihat ke berbagai menu lain tapi tidak bisa edit, mending tidak bisa lihat sekalian cukup menu issue aja sama manage customer. Ditunggu updatenya
# --------------------------------------------------
# ----------
# [79]--------------------------------------------------
# Nama user: Kinan Raharjo
# Tanggal review: October 5, 2016
# Review: 2 device 1 toko bisa bos? Trs klo sdh ada bbrp cabang,cara belinya lisensi gmn? Klo 4 cabang beli lisensinya pakai akun utama atau per device?
# --------------------------------------------------
# ----------
# [80]--------------------------------------------------
# Nama user: Danurdara Indraswara
# Tanggal review: September 20, 2016
# Review: Aplikasi yang sangat luar biasa, mudah digunakan dan sangat membantu dalam penjualan, 1 pertanyaan saya, bagaimana cara menghapus transaksi yg sudah tercatat, karena tadi hanya mencoba2 dulu. terimakasih
# --------------------------------------------------
# ----------
# [81]--------------------------------------------------
# Nama user: Rajamohan Kannan
# Tanggal review: September 17, 2016
# Review: It's really good app to run a sales and it has excellent auto backup but no search option in the reports
# --------------------------------------------------
# ----------
# [82]--------------------------------------------------
# Nama user: Jacob Kamau
# Tanggal review: September 18, 2016
# Review: Add the sales rep management I will give 5 *
# --------------------------------------------------
# ----------
# [83]--------------------------------------------------
# Nama user: kimani njoroge
# Tanggal review: October 1, 2016
# Review: Can't handle invoices
# --------------------------------------------------
# ----------
# [84]--------------------------------------------------
# Nama user: Septian Dwi Pohlan
# Tanggal review: March 7, 2018
# Review: Bisa ditingkatkan, print label pada menu received item. Dengan atau tanpa barcode akan jadi lebih baik.
# --------------------------------------------------
# ----------
# [85]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: July 15, 2016
# Review: How can I change inventory q'ty that was mistakenly input ? Also, I need to change item code but cannot.
# --------------------------------------------------
# ----------
# [86]--------------------------------------------------
# Nama user: Khan Romy
# Tanggal review: July 11, 2016
# Review: Is it free for life time ?
# --------------------------------------------------
# ----------
# [87]--------------------------------------------------
# Nama user: Ivin Asmigo
# Tanggal review: July 11, 2016
# Review: Very helpful
# --------------------------------------------------
# ----------
# [88]--------------------------------------------------
# Nama user: Gapbaby Lie
# Tanggal review: July 2, 2016
# Review: Pak mau tanya..apakah multi user tidak bisa digunakan di beberapa hp? Utk hp admin A dan hp admin B bisa tdk menggunakan device hp yang berbeda?
# --------------------------------------------------
# ----------
# [89]--------------------------------------------------
# Nama user: saravanan c
# Tanggal review: June 28, 2016
# Review: I was using ireap pos earlier it's very impressive.. now i upgraded to pro version .. In ireap pro could someone guide me in creating single store with multi user for multiple device. I'm unable to map single store with multi users while operating with different mobile devices..
# --------------------------------------------------
# ----------
# [90]--------------------------------------------------
# Nama user: Maria Judy Gabas Alcazar
# Tanggal review: June 13, 2016
# Review: This is helpful for small entrepreneurs. I would like to know how to generate the store token. It's a big help.
# --------------------------------------------------
# ----------
# [91]--------------------------------------------------
# Nama user: walang sangit
# Tanggal review: August 5, 2016
# Review: Like
# --------------------------------------------------
# ----------
# [92]--------------------------------------------------
# Nama user: Fahad Usman
# Tanggal review: June 9, 2016
# Review: Please let me know if u have any desktop version. How delete or edit any record?
# --------------------------------------------------
# ----------
# [93]--------------------------------------------------
# Nama user: Irfan Gul
# Tanggal review: May 12, 2016
# Review: In iReap lite have Pakistani currency but in pro no have.
# --------------------------------------------------
# ----------
# [94]--------------------------------------------------
# Nama user: Mihir Patel
# Tanggal review: May 17, 2016
# Review: 500 server error
# --------------------------------------------------
# ----------
# [95]--------------------------------------------------
# Nama user: Muriithi Gachithi
# Tanggal review: May 3, 2016
# Review: Its perfect
# --------------------------------------------------
# ----------
# [96]--------------------------------------------------
# Nama user: Hydra Gundam
# Tanggal review: April 21, 2016
# Review: saya pengguna ireap lite dan menunggu yg pro namun sekilas pandang saya sudah cukup dengan menggunakan versi lite. perbedaannya lite dan pro nda terlalu kentara oleh karena itu saya lebih baik menunggu update terbaru dr ireap pro saja dulu. cukup menjanjikan kok sebagai POS cashier yg professional u...
# Full Review
# --------------------------------------------------
# ----------
# [97]--------------------------------------------------
# Nama user: Frendy Budiman Suherli
# Tanggal review: April 17, 2016
# Review: Perfect :)
# --------------------------------------------------
# ----------
# [98]--------------------------------------------------
# Nama user: hadi subowo
# Tanggal review: April 10, 2016
# Review: Halo Ireap Team. How to reset password master discount? Or how to disable that
# --------------------------------------------------
# ----------
# [99]--------------------------------------------------
# Nama user: Shahrul Hafizi
# Tanggal review: April 11, 2016
# Review: Salam, Macam mana ya mahu import master data dari IReap Lite kepada iReap Pro?
# --------------------------------------------------
# ----------
# [100]--------------------------------------------------
# Nama user: Wongso Soekamto
# Tanggal review: April 8, 2016
# Review: It finally gets the multi device support!
# --------------------------------------------------
# ----------
# [101]--------------------------------------------------
# Nama user: wein kruz
# Tanggal review: April 12, 2016
# Review: Great app for retail business!
# --------------------------------------------------
# ----------
# [102]--------------------------------------------------
# Nama user: Antoine A. P.
# Tanggal review: April 7, 2016
# Review: What I like most from this app, I don't need to setup master data & settings in each device. I can manage it in the Web and then it will distribute to my devices only in seconds
# --------------------------------------------------
# ----------
# [103]--------------------------------------------------
# Nama user: Andi Kurniawan
# Tanggal review: April 8, 2016
# Review: Akhirnya hadir juga versi cloud. Good job Mr. Robby and team.
# --------------------------------------------------
# ----------
# [104]--------------------------------------------------
# Nama user: Sani Lauhatta
# Tanggal review: April 7, 2016
# Review: Sangat membantu.. Top
# --------------------------------------------------
# ----------
# [105]--------------------------------------------------
# Nama user: Djoko Kurniawan
# Tanggal review: April 7, 2016
# Review: Great!
# --------------------------------------------------
# ----------
# [106]--------------------------------------------------
# Nama user: Yohanes Christian
# Tanggal review: April 7, 2016
# Review: Top aplikasi ini sangat membantu saya...
# --------------------------------------------------
# ----------
# [107]--------------------------------------------------
# Nama user: Siddharta Liang
# Tanggal review: April 7, 2016
# Review: Perfect!!
# --------------------------------------------------
# ----------
# [108]--------------------------------------------------
# Nama user: Rini Ratna Sari
# Tanggal review: April 7, 2016
# Review: incredible apps
# --------------------------------------------------
# ----------
# [109]--------------------------------------------------
# Nama user: petrus margo
# Tanggal review: April 7, 2016
# Review: Perfect
# --------------------------------------------------
# ----------
# [110]--------------------------------------------------
# Nama user: Nicky Teguh
# Tanggal review: April 8, 2016
# Review: Powerful.
# --------------------------------------------------
# ----------
# [111]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: August 28, 2016
# Review: A great app. A couple of small problems but you can work around them
# --------------------------------------------------
# ----------
# [112]--------------------------------------------------
# Nama user: private one
# Tanggal review: April 5, 2017
# Review: update review ya, saya udh pake lama aplikasi ini dan betul2 berguna, tapi untuk masalah printer dan cetak struk/invoice tidak pakai aplikasi ireap, ada satu produk malaysia yg saya pakai,(maaf) yg sudah saya pakai selama 1 minggu ini yg support berbagai printer bluetooth, dan di menu pengaturan pri...
# Full Review
# --------------------------------------------------
# ----------
# [113]--------------------------------------------------
# Nama user: I K
# Tanggal review: November 8, 2016
# Review: Metode pembayaran lisensi yang tersedia apa saja? Jika device yang digunakan rusak atau hilang apakah harus beli lisensi kembali untuk device yang baru? Terima kasih
# --------------------------------------------------
# ----------
# [114]--------------------------------------------------
# Nama user: Angga Darwin
# Tanggal review: January 16, 2018
# Review: Terbaiiiiiikkkk!!!! UI nya sangat baik Feature-feature keren Team sangat responsive Overall terbaik dari app dari dev yang lainnya Dan yang terpenting hanya 50k/month!!!
# --------------------------------------------------
# ----------
# [115]--------------------------------------------------
# Nama user: Wawan Agus Sulistyo
# Tanggal review: April 20, 2016
# Review: Ketika setting pertama saya salah masukkan email, dan selanjutnya saya tidak bisa login. Padahal saya ingin sekali menggunakan apk ini. Jika ada solusi mohon dibalas segera. Semoga sukses dengan apk ini.. Trims..
# --------------------------------------------------
# ----------
# [116]--------------------------------------------------
# Nama user: toserba digital
# Tanggal review: August 28, 2017
# Review: Bos ane dpt voucher ireap pro dr pembelian printer bellaV, bs dbantu pencerahan untuk penggunaannya ?
# --------------------------------------------------
# ----------
# [117]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: October 10, 2017
# Review: Dear team, apakah memungkinkan ditambahkan shipping cost pada bagian penjualan, krn untuk penjualan online shipping costnya berbeda beda
# --------------------------------------------------
# ----------
# [118]--------------------------------------------------
# Nama user: Jane Budiman
# Tanggal review: January 13, 2020
# Review: Mantap, mudah dan lengkap, untuk monitor stok dan penjualan di toko, bisa untuk monitor banyak toko juga.
# --------------------------------------------------
# ----------
# [119]--------------------------------------------------
# Nama user: indry giani puspa
# Tanggal review: February 28, 2018
# Review: Apa bedanya pro sama lite yah? Newbie hehehe
# --------------------------------------------------
# ----------
# [120]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: February 17, 2019
# Review: Sayang menu untuk harga grosir belum tersedia
# --------------------------------------------------
# ----------
# [121]--------------------------------------------------
# Nama user: elizabeth yao
# Tanggal review: May 18, 2016
# Review: Apa beda yg pro dan yg lite .
# --------------------------------------------------
# ----------
# [122]--------------------------------------------------
# Nama user: Asih Sri Yamtini
# Tanggal review: May 21, 2018
# Review: Kenapa saya gak bisa download iREAP bisabantu gak
# --------------------------------------------------
# ----------
# [123]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: April 7, 2018
# Review: We need this app on iOS devices and Windows
# --------------------------------------------------
# ----------
# [124]--------------------------------------------------
# Nama user: Ekstrindo Laminasi
# Tanggal review: April 6, 2018
# Review: We use it for our sales team
# --------------------------------------------------
# ----------
# [125]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: September 26, 2018
# Review: Sangat bagus dan sangat membantu penjualan. Saya adalah pengguna ireap pro sudah hampir 1 th.. Tapi kalo boleh saran, bisa kah ditambahkan fitur paket discount? Jadi semisal customer membeli produk yang kita paketkan, akan mendapat harga yg berbeda sesuai dengan promo yg dibuat oleh toko. Dan juga s...
# Full Review
# --------------------------------------------------
# ----------
# [126]--------------------------------------------------
# Nama user: HENNY S HANDOJO
# Tanggal review: July 13, 2016
# Review: This pos helps me in managing my small stores
# --------------------------------------------------
# ----------
# [127]--------------------------------------------------
# Nama user: A Google user
# Tanggal review: February 21, 2017
# Review: This is the apps that I need for my stores. I can easily manage my stores.
# --------------------------------------------------
# ----------
# [128]--------------------------------------------------
# Nama user: Ri na
# Tanggal review: July 12, 2016
# Review: 087465556
# --------------------------------------------------
# ----------
# [129]--------------------------------------------------
# Nama user: Abdul Kodir
# Tanggal review: March 17, 2018
# Review: keren bangat
# --------------------------------------------------
# ----------
# [130]--------------------------------------------------
# Nama user: Mervin Agustino
# Tanggal review: February 23, 2017
# Review: Thank for this apps easy to used.
# --------------------------------------------------
# ----------
# [131]--------------------------------------------------
# Nama user: Jeet lal Rajbanshi
# Tanggal review: February 24, 2018
# Review: Very good app
# --------------------------------------------------
# ----------
# [132]--------------------------------------------------
# Nama user: Tophy Mwale
# Tanggal review: March 3, 2018
# Review: Good app guys
# --------------------------------------------------
# ----------
# [133]--------------------------------------------------
# Nama user: Nazish Khalid
# Tanggal review: October 7, 2017
# Review: Bad.
# --------------------------------------------------
# ----------
# [134]--------------------------------------------------
# Nama user: Anita DS
# Tanggal review: March 7, 2017
# Review: Jos
# --------------------------------------------------
# ----------
# [135]--------------------------------------------------
# Nama user: Frans Fillipus
# Tanggal review: May 23, 2020
# Review: perfect ever
# --------------------------------------------------
# ----------
# [136]--------------------------------------------------
# Nama user: Md Rakib Rana
# Tanggal review: February 18, 2019
# Review: 💯 ♥️ ☀️
# --------------------------------------------------
# ----------

# %%
reviews_df = pd.concat(reviews_df,ignore_index=True)

# %%
reviews_df.to_csv('reviews_ireappro.csv', encoding='utf-8')

# %%
reviews_df
# Out:
#                  Nama            Tanggal  \
# 0       Nwokoro Peter  February 24, 2020
# 1            Hi10 Thk     March 21, 2020
# 2        Siliki Sprei  November 15, 2019
# 3       Irish De Luna       May 13, 2019
# 4    Yulianto 9unawan  November 15, 2019
# ..                ...                ...
# 131       Tophy Mwale      March 3, 2018
# 132     Nazish Khalid    October 7, 2017
# 133          Anita DS      March 7, 2017
# 134    Frans Fillipus       May 23, 2020
# 135     Md Rakib Rana  February 18, 2019
#
#                                                Reviews
# 0    very useful, second to none, but improve on ex...
# 1    For products need to add photo options, so we ...
# 2     Nice to trial this app , very usefull and Simple
# 3    Please provide customer loyalty program also t...
# 4    I am Coffeepreneur with brand Nomar Kopi, foun...
# ..                                                 ...
# 131                                      Good app guys
# 132                                               Bad.
# 133                                                Jos
# 134                                       perfect ever
# 135                                            💯 ♥️ ☀️
#
# [136 rows x 3 columns]

# %%
rating=driver.find_elements_by_xpath(".//div[@class='vQHuPe bUWb7c']")

print ('Ratings: '+str(len(rating)))
# Out:
# Ratings: 651

# %%
print('data reviews terunduh '+str(len(reviews))+' buah')
# Out:
# data reviews terunduh 136 buah
